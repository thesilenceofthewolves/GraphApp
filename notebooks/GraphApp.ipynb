# %%
# !pip install -q azure-identity
# !pip install -q msal azure-identity msgraph-sdk flask
from configparser import SectionProxy
from azure.identity.aio import ClientSecretCredential
from msgraph import GraphServiceClient
from msgraph.generated.users.users_request_builder import UsersRequestBuilder

# %%
#install package
# !pip install -q msal azure-identity msgraph-sdk flask

# %%
import os
from getpass import getpass

client_id = input("Client ID: ")
tenant_id = input("Tenant ID: ")
client_secret = getpass("Client Secret: ")

os.environ["CLIENT_ID"] = client_id
os.environ["TENANT_ID"] = tenant_id
os.environ["CLIENT_SECRET"] = client_secret
# Out:
# Client ID: 320b78e2-0572-41a9-9f83-f1dd3a0a3ea8
# Tenant ID: 46e7450c-343b-4cad-9ea0-7c8e917ddf0b
# Client Secret: ··········

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive/app/

#if the file alreay exist remove it
# !rm -rf GraphApp
# !git clone https://github.com/thesilenceofthewolves/GraphApp.git
# %cd GraphApp/data
# !python main.py


# !python main.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/app
# Python Graph App-Only Tutorial
#
# Please choose one of the following options:
# 0. Exit
# 1. Display access token
# 2. List users
# 3. Make a Graph call
# 0
# Goodbye...
